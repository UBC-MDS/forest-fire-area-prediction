# %%
import numpy as np
import pandas as pd
from sklearn.model_selection import train_test_split

# %%
def  seasons(df):
    seasons = ["NONE"] * len(df)
    for x in range(0, len(df)):
        m = df.loc[x, "month"]
        if m in ["dec", "jan", "feb"]:
            seasons[x] = "winter"
        elif m in ["mar", "apr", "may"]:
            seasons[x] = "spring"
        elif m in ["jun", "jul", "aug"]:
            seasons[x] = "summer"
        elif m in ["sep", "oct", "nov"]:
            seasons[x] = "fall"
    return (seasons)

# %%
ff_data = pd.read_csv(
    "C:/Users/margo.DESKTOP-T66VM01/Desktop/UBC_Program/522_workflows/forest-fire-area-prediction-group-2/data/raw/forestfires.csv"
)
seasons = seasons(ff_data)

ff_data["season"] = seasons

ff_data["fire"] = 0
ff_data["rain_cat"] = 0
ff_data.loc[ff_data.area > 0, "fire"] = 1
ff_data.loc[ff_data.rain > 0, "rain_cat"] = 1
ff_data = ff_data.drop(499, axis =0)
ff_data = ff_data.drop("area", axis =1 )
ff_data

train_df, test_df = train_test_split(ff_data, test_size=0.2, random_state=123)

# %%
df = ff_data
winter = df.loc[(df.month == "dec") | (df.month == "feb")|(df.month =="jan")].index
spring = df.loc[(df.month == "mar") | (df.month == "apr")|(df.month =="may")].index
summer = df.loc[(df.month == "jun") | (df.month == "jul")|(df.month =="aug")].index
fall = df.loc[(df.month == "sep") | (df.month == "oct")|(df.month =="nov")].index

import altair as alt
alt.Chart(train_df).mark_bar().encode(
        x="area_log", y="count()")
# Out:
# alt.Chart(...)

# %%
ff_data["fire"] = 0
ff_data["rain_cat"] = 0
ff_data.loc[ff_data.area > 0, "fire"] = 1
ff_data.loc[ff_data.rain > 0, "rain_cat"] = 1
ff_data = ff_data.drop(499, axis =0)
ff_data = ff_data.drop("area", axis =1 )
ff_data
# Out:
#      X  Y month  day  FFMC    DMC     DC   ISI  temp  RH  wind  rain  season  \
# 0    7  5   mar  fri  86.2   26.2   94.3   5.1   8.2  51   6.7   0.0  spring
# 1    7  4   oct  tue  90.6   35.4  669.1   6.7  18.0  33   0.9   0.0    fall
# 2    7  4   oct  sat  90.6   43.7  686.9   6.7  14.6  33   1.3   0.0    fall
# 3    8  6   mar  fri  91.7   33.3   77.5   9.0   8.3  97   4.0   0.2  spring
# 4    8  6   mar  sun  89.3   51.3  102.2   9.6  11.4  99   1.8   0.0  spring
# ..  .. ..   ...  ...   ...    ...    ...   ...   ...  ..   ...   ...     ...
# 512  4  3   aug  sun  81.6   56.7  665.6   1.9  27.8  32   2.7   0.0  summer
# 513  2  4   aug  sun  81.6   56.7  665.6   1.9  21.9  71   5.8   0.0  summer
# 514  7  4   aug  sun  81.6   56.7  665.6   1.9  21.2  70   6.7   0.0  summer
# 515  1  4   aug  sat  94.4  146.0  614.7  11.3  25.6  42   4.0   0.0  summer
# 516  6  3   nov  tue  79.5    3.0  106.7   1.1  11.8  31   4.5   0.0    fall
#
#      fire rain_cat
# 0       0     None
# 1       0     None
# 2       0     None
# 3       0        1
# 4       0     None
# ..    ...      ...
# 512     1     None
# 513     1     None
# 514     1     None
# 515     0     None
# 516     0     None
#
# [516 rows x 15 columns]

# %%
ff_data.loc[ff_data.rain==max(ff_data.rain)]
# Out:
#      X  Y month  day  FFMC    DMC     DC  ISI  temp  RH  wind  rain  season  \
# 509  5  4   aug  fri  91.0  166.9  752.6  7.1  21.1  71   7.6   1.4  summer
#
#      fire rain_cat
# 509     1        1
